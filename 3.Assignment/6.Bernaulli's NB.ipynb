# %%
import pandas as pd
dataset = pd.read_csv("CKD.csv")
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset.columns

#independent, dependent variable
independent = dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent = dataset[['classification_yes']]

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
independent = sc.fit_transform(independent)
independent = sc.transform(independent)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import GridSearchCV
grid_param = {
    'alpha': [0.1, 0.5, 1.0, 2.0],
    'binarize': [0.0, 0.5, 1.0]
}
grid = GridSearchCV(BernoulliNB(), grid_param, refit=True, verbose=3,scoring='f1_weighted')
grid.fit(independent, dependent)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ...........alpha=0.1, binarize=0.0;, score=0.938 total time=   0.0s
# [CV 2/5] END ...........alpha=0.1, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=0.1, binarize=0.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=0.1, binarize=0.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=0.1, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=0.1, binarize=0.5;, score=0.938 total time=   0.0s
# [CV 2/5] END ...........alpha=0.1, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=0.1, binarize=0.5;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=0.1, binarize=0.5;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=0.1, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=0.1, binarize=1.0;, score=0.914 total time=   0.0s
# [CV 2/5] END ...........alpha=0.1, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=0.1, binarize=1.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=0.1, binarize=1.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=0.1, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=0.5, binarize=0.0;, score=0.926 total time=   0.0s
# [CV 2/5] END ...........alpha=0.5, binarize=0.0;, score=0.975 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ...........alpha=0.5, binarize=0.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=0.5, binarize=0.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=0.5, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=0.5, binarize=0.5;, score=0.938 total time=   0.0s
# [CV 2/5] END ...........alpha=0.5, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=0.5, binarize=0.5;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=0.5, binarize=0.5;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=0.5, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=0.5, binarize=1.0;, score=0.902 total time=   0.0s
# [CV 2/5] END ...........alpha=0.5, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=0.5, binarize=1.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=0.5, binarize=1.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=0.5, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=1.0, binarize=0.0;, score=0.926 total time=   0.0s
# [CV 2/5] END ...........alpha=1.0, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=1.0, binarize=0.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=1.0, binarize=0.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=1.0, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=1.0, binarize=0.5;, score=0.926 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ...........alpha=1.0, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=1.0, binarize=0.5;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=1.0, binarize=0.5;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=1.0, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=1.0, binarize=1.0;, score=0.902 total time=   0.0s
# [CV 2/5] END ...........alpha=1.0, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=1.0, binarize=1.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=1.0, binarize=1.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=1.0, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=2.0, binarize=0.0;, score=0.827 total time=   0.0s
# [CV 2/5] END ...........alpha=2.0, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=2.0, binarize=0.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=2.0, binarize=0.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=2.0, binarize=0.0;, score=0.975 total time=   0.0s
# [CV 1/5] END ...........alpha=2.0, binarize=0.5;, score=0.827 total time=   0.0s
# [CV 2/5] END ...........alpha=2.0, binarize=0.5;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=2.0, binarize=0.5;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=2.0, binarize=0.5;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=2.0, binarize=0.5;, score=0.975 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ...........alpha=2.0, binarize=1.0;, score=0.889 total time=   0.0s
# [CV 2/5] END ...........alpha=2.0, binarize=1.0;, score=0.975 total time=   0.0s
# [CV 3/5] END ...........alpha=2.0, binarize=1.0;, score=0.988 total time=   0.0s
# [CV 4/5] END ...........alpha=2.0, binarize=1.0;, score=1.000 total time=   0.0s
# [CV 5/5] END ...........alpha=2.0, binarize=1.0;, score=0.975 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=BernoulliNB(),
#              param_grid={'alpha': [0.1, 0.5, 1.0, 2.0],
#                          'binarize': [0.0, 0.5, 1.0]},
#              scoring='f1_weighted', verbose=3)

# %%
grid_pred = grid.predict(independent)

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(dependent, grid_pred)

# %%
from sklearn.metrics import classification_report
cf_report = classification_report(dependent, grid_pred)

# %%
print(cf_matrix)
# Out:
# [[149   1]
#  [  9 240]]

# %%
print(cf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       150
#            1       1.00      0.96      0.98       249
#
#     accuracy                           0.97       399
#    macro avg       0.97      0.98      0.97       399
# weighted avg       0.98      0.97      0.98       399

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(dependent, grid.predict_proba(independent)[:,1])
# Out:
# 0.991285140562249

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(dependent,grid_pred, average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'alpha': 0.1, 'binarize': 0.0}: 0.9750582392902479

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.006133      0.010230         0.008200        0.007032         0.1
# 1        0.001425      0.001502         0.009831        0.003760         0.1
# 2        0.003129      0.006257         0.004744        0.006279         0.1
# 3        0.004504      0.004050         0.009873        0.005351         0.5
# 4        0.004968      0.002853         0.006698        0.003559         0.5
# 5        0.000000      0.000000         0.009057        0.007418         0.5
# 6        0.000000      0.000000         0.009374        0.007654         1.0
# 7        0.007186      0.006120         0.006124        0.003787         1.0
# 8        0.001879      0.003759         0.006148        0.003585         1.0
# 9        0.003125      0.006250         0.006250        0.007655         2.0
# 10       0.006028      0.007391         0.003733        0.006652         2.0
# 11       0.003273      0.003277         0.009173        0.005522         2.0
#
#    param_binarize                           params  split0_test_score  \
# 0             0.0  {'alpha': 0.1, 'binarize': 0.0}           0.938259
# 1             0.5  {'alpha': 0.1, 'binarize': 0.5}           0.938259
# 2             1.0  {'alpha': 0.1, 'binarize': 1.0}           0.913778
# 3             0.0  {'alpha': 0.5, 'binarize': 0.0}           0.926015
# 4             0.5  {'alpha': 0.5, 'binarize': 0.5}           0.938259
# 5             1.0  {'alpha': 0.5, 'binarize': 1.0}           0.901535
# 6             0.0  {'alpha': 1.0, 'binarize': 0.0}           0.926015
# 7             0.5  {'alpha': 1.0, 'binarize': 0.5}           0.926015
# 8             1.0  {'alpha': 1.0, 'binarize': 1.0}           0.901535
# 9             0.0  {'alpha': 2.0, 'binarize': 0.0}           0.827310
# 10            0.5  {'alpha': 2.0, 'binarize': 0.5}           0.827310
# 11            1.0  {'alpha': 2.0, 'binarize': 1.0}           0.889274
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.975148           0.987539                1.0
# 1            0.975148           0.987539                1.0
# 2            0.975148           0.987539                1.0
# 3            0.975148           0.987539                1.0
# 4            0.975148           0.987539                1.0
# 5            0.975148           0.987539                1.0
# 6            0.975148           0.987539                1.0
# 7            0.975148           0.987539                1.0
# 8            0.975148           0.987539                1.0
# 9            0.975148           0.987539                1.0
# 10           0.975148           0.987539                1.0
# 11           0.975148           0.987539                1.0
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.974684         0.975126        0.020650                1
# 1            0.974684         0.975126        0.020650                1
# 2            0.974684         0.970230        0.029721                7
# 3            0.974684         0.972677        0.025119                4
# 4            0.974684         0.975126        0.020650                1
# 5            0.974684         0.967781        0.034406                8
# 6            0.974684         0.972677        0.025119                4
# 7            0.974684         0.972677        0.025119                4
# 8            0.974684         0.967781        0.034406                8
# 9            0.974684         0.952936        0.063499               11
# 10           0.974684         0.952936        0.063499               11
# 11           0.974684         0.965329        0.039150               10
