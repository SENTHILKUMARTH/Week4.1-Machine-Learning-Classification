# %%
import pandas as pd
dataset = pd.read_csv("CKD.csv")
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset.columns

#independent, dependent variable
independent = dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent = dataset[['classification_yes']]

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

grid_param = {
            'alpha':[1.0, 2.0,30,4.0,5.0],
            'force_alpha':[True, False]
}

grid = GridSearchCV(MultinomialNB(), grid_param, refit = True, verbose = 3, scoring='f1_weighted')
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .......alpha=1.0, force_alpha=True;, score=0.659 total time=   0.0s
# [CV 2/5] END .......alpha=1.0, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 3/5] END .......alpha=1.0, force_alpha=True;, score=0.914 total time=   0.0s
# [CV 4/5] END .......alpha=1.0, force_alpha=True;, score=0.914 total time=   0.0s
# [CV 5/5] END .......alpha=1.0, force_alpha=True;, score=0.924 total time=   0.0s
# [CV 1/5] END ......alpha=1.0, force_alpha=False;, score=0.659 total time=   0.0s
# [CV 2/5] END ......alpha=1.0, force_alpha=False;, score=0.865 total time=   0.0s
# [CV 3/5] END ......alpha=1.0, force_alpha=False;, score=0.914 total time=   0.0s
# [CV 4/5] END ......alpha=1.0, force_alpha=False;, score=0.914 total time=   0.0s
# [CV 5/5] END ......alpha=1.0, force_alpha=False;, score=0.924 total time=   0.0s
# [CV 1/5] END .......alpha=2.0, force_alpha=True;, score=0.645 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .......alpha=2.0, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 3/5] END .......alpha=2.0, force_alpha=True;, score=0.889 total time=   0.0s
# [CV 4/5] END .......alpha=2.0, force_alpha=True;, score=0.902 total time=   0.0s
# [CV 5/5] END .......alpha=2.0, force_alpha=True;, score=0.924 total time=   0.0s
# [CV 1/5] END ......alpha=2.0, force_alpha=False;, score=0.645 total time=   0.0s
# [CV 2/5] END ......alpha=2.0, force_alpha=False;, score=0.865 total time=   0.0s
# [CV 3/5] END ......alpha=2.0, force_alpha=False;, score=0.889 total time=   0.0s
# [CV 4/5] END ......alpha=2.0, force_alpha=False;, score=0.902 total time=   0.0s
# [CV 5/5] END ......alpha=2.0, force_alpha=False;, score=0.924 total time=   0.0s
# [CV 1/5] END ........alpha=30, force_alpha=True;, score=0.601 total time=   0.0s
# [CV 2/5] END ........alpha=30, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 3/5] END ........alpha=30, force_alpha=True;, score=0.828 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ........alpha=30, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 5/5] END ........alpha=30, force_alpha=True;, score=0.875 total time=   0.0s
# [CV 1/5] END .......alpha=30, force_alpha=False;, score=0.601 total time=   0.0s
# [CV 2/5] END .......alpha=30, force_alpha=False;, score=0.865 total time=   0.0s
# [CV 3/5] END .......alpha=30, force_alpha=False;, score=0.828 total time=   0.0s
# [CV 4/5] END .......alpha=30, force_alpha=False;, score=0.865 total time=   0.0s
# [CV 5/5] END .......alpha=30, force_alpha=False;, score=0.875 total time=   0.0s
# [CV 1/5] END .......alpha=4.0, force_alpha=True;, score=0.630 total time=   0.0s
# [CV 2/5] END .......alpha=4.0, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 3/5] END .......alpha=4.0, force_alpha=True;, score=0.877 total time=   0.0s
# [CV 4/5] END .......alpha=4.0, force_alpha=True;, score=0.902 total time=   0.0s
# [CV 5/5] END .......alpha=4.0, force_alpha=True;, score=0.900 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ......alpha=4.0, force_alpha=False;, score=0.630 total time=   0.0s
# [CV 2/5] END ......alpha=4.0, force_alpha=False;, score=0.865 total time=   0.0s
# [CV 3/5] END ......alpha=4.0, force_alpha=False;, score=0.877 total time=   0.0s
# [CV 4/5] END ......alpha=4.0, force_alpha=False;, score=0.902 total time=   0.0s
# [CV 5/5] END ......alpha=4.0, force_alpha=False;, score=0.900 total time=   0.0s
# [CV 1/5] END .......alpha=5.0, force_alpha=True;, score=0.616 total time=   0.0s
# [CV 2/5] END .......alpha=5.0, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 3/5] END .......alpha=5.0, force_alpha=True;, score=0.865 total time=   0.0s
# [CV 4/5] END .......alpha=5.0, force_alpha=True;, score=0.902 total time=   0.0s
# [CV 5/5] END .......alpha=5.0, force_alpha=True;, score=0.900 total time=   0.0s
# [CV 1/5] END ......alpha=5.0, force_alpha=False;, score=0.616 total time=   0.0s
# [CV 2/5] END ......alpha=5.0, force_alpha=False;, score=0.865 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ......alpha=5.0, force_alpha=False;, score=0.865 total time=   0.0s
# [CV 4/5] END ......alpha=5.0, force_alpha=False;, score=0.902 total time=   0.0s
# [CV 5/5] END ......alpha=5.0, force_alpha=False;, score=0.900 total time=   0.0s
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=MultinomialNB(),
#              param_grid={'alpha': [1.0, 2.0, 30, 4.0, 5.0],
#                          'force_alpha': [True, False]},
#              scoring='f1_weighted', verbose=3)

# %%
grid_pred = grid.predict(independent)

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(dependent, grid_pred)

# %%
from sklearn.metrics import classification_report
cf_report = classification_report(dependent, grid_pred)

# %%
print(cf_matrix)
print(cf_report)
# Out:
# [[145   5]
#  [ 54 195]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.83       150
#            1       0.97      0.78      0.87       249
#
#     accuracy                           0.85       399
#    macro avg       0.85      0.87      0.85       399
# weighted avg       0.88      0.85      0.85       399

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(dependent, grid.predict_proba(independent)[:,1])
# Out:
# 0.9499866131191431

# %%
from sklearn.metrics import f1_score
f1_score = f1_score(dependent, grid_pred, average = 'weighted')
print("evaluation metrics {}:".format(grid.best_params_),f1_score)
# Out:
# evaluation metrics {'alpha': 1.0, 'force_alpha': True}: 0.8544422491701906

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.010968      0.012924         0.012763        0.002466         1.0
# 1       0.012264      0.002574         0.002023        0.001824         1.0
# 2       0.011167      0.004469         0.008250        0.005150         2.0
# 3       0.006648      0.000828         0.010862        0.003090         2.0
# 4       0.003075      0.006151         0.015553        0.000151          30
# 5       0.008190      0.000872         0.009866        0.001573          30
# 6       0.001167      0.002334         0.015325        0.004926         4.0
# 7       0.006846      0.004788         0.013084        0.002658         4.0
# 8       0.004705      0.003231         0.010433        0.003635         5.0
# 9       0.003622      0.005028         0.011733        0.006053         5.0
#
#   param_force_alpha                                params  split0_test_score  \
# 0              True   {'alpha': 1.0, 'force_alpha': True}           0.658856
# 1             False  {'alpha': 1.0, 'force_alpha': False}           0.658856
# 2              True   {'alpha': 2.0, 'force_alpha': True}           0.644737
# 3             False  {'alpha': 2.0, 'force_alpha': False}           0.644737
# 4              True    {'alpha': 30, 'force_alpha': True}           0.600968
# 5             False   {'alpha': 30, 'force_alpha': False}           0.600968
# 6              True   {'alpha': 4.0, 'force_alpha': True}           0.630392
# 7             False  {'alpha': 4.0, 'force_alpha': False}           0.630392
# 8              True   {'alpha': 5.0, 'force_alpha': True}           0.615808
# 9             False  {'alpha': 5.0, 'force_alpha': False}           0.615808
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.864654           0.913563           0.913778           0.924484
# 1           0.864654           0.913563           0.913778           0.924484
# 2           0.864654           0.889143           0.901535           0.924484
# 3           0.864654           0.889143           0.901535           0.924484
# 4           0.864654           0.827652           0.864654           0.875044
# 5           0.864654           0.827652           0.864654           0.875044
# 6           0.864654           0.876918           0.901535           0.899744
# 7           0.864654           0.876918           0.901535           0.899744
# 8           0.864654           0.864668           0.901535           0.899744
# 9           0.864654           0.864668           0.901535           0.899744
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.855067        0.100278                1
# 1         0.855067        0.100278                1
# 2         0.844911        0.101935                3
# 3         0.844911        0.101935                3
# 4         0.806594        0.104070                9
# 5         0.806594        0.104070                9
# 6         0.834649        0.103072                5
# 7         0.834649        0.103072                5
# 8         0.829282        0.107944                7
# 9         0.829282        0.107944                7
